# %%
#Getting and knowing data

# %%
import pandas as pd
import numpy as np
import os
print(os.getcwd())
# Out:
# C:\Users\Admin\Documents\Knowing_DATA

# %%
#STEP 1 : INPUT DATA

# %%
df = pd.read_csv("chipotle.tsv", sep = "\t")

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#step 2: dataset overview

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   str
#  3   choice_description  3376 non-null   str
#  4   item_price          4622 non-null   str
# dtypes: int64(2), str(3)
# memory usage: 490.3 KB

# %%
list(df.columns)
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
###loc and iloc // loc: location iloc: index_location

# %%
df.loc[(df.quantity == 15) | (df.item_name == "Chicken Bowl"), ["item_price", "choice_description"]]
# Out:
#      item_price                                 choice_description
# 4       $16.98   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5       $10.98   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 13      $11.25   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 19       $8.75   [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 26       $8.49   [Roasted Chili Corn Salsa (Medium), [Pinto Bea...
# ...         ...                                                ...
# 4590    $11.25   [Roasted Chili Corn Salsa, [Rice, Black Beans,...
# 4591     $8.75   [Tomatillo Red Chili Salsa, [Rice, Black Beans...
# 4595     $8.75   [Tomatillo Green Chili Salsa, [Rice, Black Bea...
# 4599     $8.75       [Roasted Chili Corn Salsa, [Cheese, Lettuce]]
# 4604     $8.75   [Fresh Tomato Salsa, [Rice, Black Beans, Chees...
#
# [727 rows x 2 columns]

# %%
df.iloc[9]
# Out:
# order_id                                                              5
# quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# item_price                                                       $9.25
# Name: 9, dtype: object

# %%
df.iloc[[9]]
# Out:
#    order_id  quantity      item_name  \
# 9         5         1  Steak Burrito
#
#                                   choice_description item_price
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
df.iloc[3:5, -1]
# Out:
# 3     $2.39
# 4    $16.98
# Name: item_price, dtype: str

# %%
df.iloc[3:5, 0:-1]
# Out:
#    order_id  quantity                              item_name  \
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description
# 3                                                NaN
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...

# %%
### thao tac tren data

# %%
df.item_price.dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
### apply()
df.item_price = df.item_price.apply(lambda x : float(x.replace('$', '')))

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
df["total_price"] = df["item_price"]*df["quantity"]

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  total_price
# 0                                                NaN        2.39         2.39
# 1                                       [Clementine]        3.39         3.39
# 2                                            [Apple]        3.39         3.39
# 3                                                NaN        2.39         2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        33.96

# %%
## tinh tong gia trij ban duoc
df['total_price'].sum()
# Out:
# np.float64(39237.02)

# %%
## tim hang nao duoc oder nhieu nhat
c = df.groupby("item_name")["quantity"].sum()
c.sort_values()
# Out:
# item_name
# Carnitas Salad                             1
# Chips and Mild Fresh Tomato Salsa          1
# Veggie Crispy Tacos                        1
# Crispy Tacos                               2
# Salad                                      2
# Steak Salad                                4
# Bowl                                       4
# Burrito                                    6
# Carnitas Salad Bowl                        6
# Veggie Salad                               6
# Veggie Soft Tacos                          8
# Carnitas Crispy Tacos                      8
# Chicken Salad                              9
# Barbacoa Salad Bowl                       10
# Barbacoa Crispy Tacos                     12
# Chips and Roasted Chili-Corn Salsa        18
# Veggie Salad Bowl                         18
# Izze                                      20
# Chips and Roasted Chili Corn Salsa        23
# Barbacoa Soft Tacos                       25
# Chips and Tomatillo-Red Chili Salsa       25
# ...

# %%
c.sort_values(ascending = 0)
# Out:
# item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# ...

# %%
c.sort_values(ascending = 0).head(5)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %%
## nhung gia tri duy nhat khong lap lai
df["item_name"].value_counts().count()
# Out:
# np.int64(50)
